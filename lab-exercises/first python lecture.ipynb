# %%
3 + 5 * 4
# Out:
# 23

# %%
#Using Python as a calculator

# %%
print(weight_kg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f7d9baf0efef> in <module>
# ----> 1 print(weight_kg)
#
# NameError: name 'weight_kg' is not defined

# %%
weight_kg = 60

# %%
print(weight_kg)
# Out:
# 60

# %%
weight_kg_text = 'weight in kilograms:'
print(weight_kg_text, weight_kg)
print('weight in pounds:', weight_kg * 2.2)
# Out:
# weight in kilograms: 60
# weight in pounds: 132.0

# %%
first, second = 'Grace', 'Shawn'

# %%
import numpy

# %%
medical_data = numpy.loadtxt(fname='inflammation-01.csv', delimiter=',')

# %%
print(medical_data)
# Out:
# [[0. 0. 1. ... 3. 0. 0.]
#  [0. 1. 2. ... 1. 0. 1.]
#  [0. 1. 1. ... 2. 1. 1.]
#  ...
#  [0. 0. 1. ... 3. 0. 0.]
#  [0. 1. 2. ... 1. 0. 1.]
#  [0. 1. 1. ... 2. 1. 1.]]

# %%
import numpy as np
medical_data = np.loadtxt(fname='inflammation-01.csv', delimiter=',')

# %%
#array
a = [1,2,3,4]

# %%
print(a)
# Out:
# [1, 2, 3, 4]

# %%
print(a[0])
# Out:
# 1

# %%
print(type(medical_data))
# Out:
# <class 'numpy.ndarray'>

# %%
#data types
##ints = 3, 6, 100
##floating point numbers: 2.3, 4.322, 5.322

# %%
print(medical_data.shape)
#(rows, col)
# Out:
# (54, 40)

# %%
print('first value in medical data:',medical_data[0,0])
# Out:
# first value in medical data: 0.0

# %%
print('middle value in data:',medical_data[30,20])
# Out:
# middle value in data: 6.0

# %%
med_data_shape = medical_data.shape

# %%
print(med_data_shape)
# Out:
# (54, 40)

# %%
print(med_data_shape[0])
# Out:
# 54

# %%
print(med_data_shape[1])
# Out:
# 40

# %%
middle_row = int(med_data_shape[0]/2)

# %%
middle_col = int(med_data_shape[1]/2)

# %%
print(middle_row, middle_col)
# Out:
# 27 20

# %%
print('actual middle of dataset:', medical_data[middle_row, middle_col])
# Out:
# actual middle of dataset: 6.0

# %%
print(medical_data[0:4, 0:10])
# Out:
# [[0. 0. 1. 3. 1. 2. 4. 7. 8. 3.]
#  [0. 1. 2. 1. 2. 1. 3. 2. 2. 6.]
#  [0. 1. 1. 3. 3. 2. 6. 2. 5. 9.]
#  [0. 0. 1. 3. 1. 2. 4. 7. 8. 3.]]

# %%
bruin = medical_data[:3, 36:]

# %%
print(bruin)
# Out:
# [[2. 3. 0. 0.]
#  [1. 1. 0. 1.]
#  [2. 2. 1. 1.]]

# %%
print('bruin is:\n',bruin)
# Out:
# bruin is:
#  [[2. 3. 0. 0.]
#  [1. 1. 0. 1.]
#  [2. 2. 1. 1.]]

# %%
print(np.mean(medical)data)
# Out:
#   File "<ipython-input-49-0232c8237637>", line 1
#     print(np.mean(medical)data)
#                              ^
# SyntaxError: invalid syntax

# %%
import time
print(time.ctime())
#don't need anything in the parenthesis for some things
# Out:
# Mon Jan 27 09:42:45 2020

# %%
maxval, minval = np.max(medical_data), np.min(medical_data)

# %%
stdval = np.std(medical_data)

# %%
print('max:',maxval,', min:',minval,',stdev:',stdval)
# Out:
# max: 19.0 , min: 0.0 ,stdev: 4.352194529455482

# %%
patient_0 = medical_data[0,:]

# %%
print(patient_0)
# Out:
# [ 0.  0.  1.  3.  1.  2.  4.  7.  8.  3.  3.  3. 10.  5.  7.  4.  7.  7.
#  12. 18.  6. 13. 11. 11.  7.  7.  4.  6.  8.  8.  4.  4.  5.  7.  3.  4.
#   2.  3.  0.  0.]

# %%
print('max inflammation for patient 0:', np.max(patient_0))
# Out:
# max inflammation for patient 0: 18.0

# %%
patient_2 = medical_data[1,:]
patient_2_min = np.min(patient_2)
print(patient_2_min)
# Out:
# 0.0

# %%
print(np.mean(medical_data, axis=1))
# Out:
# [5.45  5.425 6.1   5.45  5.425 6.1   5.45  5.425 6.1   5.45  5.425 6.1
#  5.45  5.425 6.1   5.45  5.425 6.1   5.45  5.425 6.1   5.45  5.425 6.1
#  5.45  5.425 6.1   5.45  5.425 6.1   5.45  5.425 6.1   5.45  5.425 6.1
#  5.45  5.425 6.1   5.45  5.425 6.1   5.45  5.425 6.1   5.45  5.425 6.1
#  5.45  5.425 6.1   5.45  5.425 6.1  ]

# %%
#axis = 0 ~> gives us whatever function for each day (column-down)
#axis = 1 ~> gives us whatever function for each patient (row-across)
patient_means_down = np.mean(medical_data, axis=0)
print(patient_means_down)
# Out:
# [ 0.          0.66666667  1.33333333  2.33333333  2.          1.66666667
#   4.33333333  3.66666667  5.          6.          6.          7.
#   6.33333333  6.33333333  5.          7.66666667  6.33333333 11.33333333
#   9.66666667 11.33333333 14.33333333 10.33333333 11.66666667 11.
#   8.66666667  8.66666667  8.66666667  6.          7.66666667  4.33333333
#   5.66666667  4.66666667  4.33333333  4.33333333  3.33333333  4.
#   1.66666667  2.          0.33333333  0.66666667]

# %%
patient_means_down = np.mean(medical_data, axis=0)
print(patient_means_down.shape)
# Out:
# (40,)

# %%
patient_means_down = np.mean(medical_data, axis=1)
print(patient_means_down)
# Out:
# [5.45  5.425 6.1   5.45  5.425 6.1   5.45  5.425 6.1   5.45  5.425 6.1
#  5.45  5.425 6.1   5.45  5.425 6.1   5.45  5.425 6.1   5.45  5.425 6.1
#  5.45  5.425 6.1   5.45  5.425 6.1   5.45  5.425 6.1   5.45  5.425 6.1
#  5.45  5.425 6.1   5.45  5.425 6.1   5.45  5.425 6.1   5.45  5.425 6.1
#  5.45  5.425 6.1   5.45  5.425 6.1  ]

# %%
#gives the length
patient_means_down = np.mean(medical_data, axis=0)
print(len(patient_means_down))
# Out:
# 40

# %%
#To write a function
def my_func(name):
    print('Hello', name)

# %%
my_func("shawn")
# Out:
# Hello shawn

# %%
def square_minus(x):
    square = x*x
    square = square - 2
    return(square)

# %%
zzz = square_minus(4)
print(zzz)
# Out:
# 14

# %%
def square_minus(x, y, name):
    my_func(name)
    return((x*y)-2)

# %%
zzz = square_minus(10,1,"Shawn")
print(zzz)
# Out:
# Hello Shawn
# 8

# %%
element = 'oxygen'

# %%
print ('first three characters:', element [0:3])
# Out:
# first three characters: oxy

# %%
print ('last three characters:', element[3:6])
# Out:
# last three characters: gen

# %%
print (element[:4])
# Out:
# oxyg

# %%
print (element[4:])
# Out:
# en

# %%
print (element[:])
# Out:
# oxygen

# %%
print (element [-1])
# Out:
# n

# %%
print (element[-2])
# Out:
# e

# %%
print (element[1:-1])
# Out:
# xyge

# %%
print (element[3:3])

# %%
print (element[3:3, 4:4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-886d1d5d45e1> in <module>
# ----> 1 print (element[3:3, 4:4])
#
# TypeError: string indices must be integers

# %%
print (medical_data[3:3])
# Out:
# []

# %%
print (medical_data[3:3, 4:4])
# Out:
# []

# %%
print (medical_data[3:3, :])
# Out:
# []

# %%
print(medical_data)
# Out:
# [[0. 0. 1. ... 3. 0. 0.]
#  [0. 1. 2. ... 1. 0. 1.]
#  [0. 1. 1. ... 2. 1. 1.]
#  ...
#  [0. 0. 1. ... 3. 0. 0.]
#  [0. 1. 2. ... 1. 0. 1.]
#  [0. 1. 1. ... 2. 1. 1.]]

# %%
print(medical_data[1:2])
# Out:
# [[ 0.  1.  2.  1.  2.  1.  3.  2.  2.  6. 10. 11.  5.  9.  4.  4.  7. 16.
#    8.  6. 18.  4. 12.  5. 12.  7. 11.  5. 11.  3.  3.  5.  4.  4.  5.  5.
#    1.  1.  0.  1.]]

# %%
print(type(medical_data))
# Out:
# <class 'numpy.ndarray'>

# %%
print(medical_data[3:3])
# Out:
# []

# %%
print(medical_data[3:3, :])
# Out:
# []

# %%
print(medical_data.shape)
# Out:
# (54, 40)

# %%
npdiff = numpy.array([medical_data])

# %%
X = numpy.diff(npdiff)

# %%
print (numpy.diff(npdiff))
# Out:
# [[[  1.   1.  -1.   1.  -1.   2.  -1.   0.   4.   4.   1.  -6.   4.  -5.
#      0.   3.   9.  -8.  -2.  12. -14.   8.  -7.   7.  -5.   4.  -6.   6.
#     -8.   0.   2.  -1.   0.   1.   0.  -4.   0.  -1.   1.]]]

# %%
print(medical_data[1:2])
# Out:
# [[ 0.  1.  2.  1.  2.  1.  3.  2.  2.  6. 10. 11.  5.  9.  4.  4.  7. 16.
#    8.  6. 18.  4. 12.  5. 12.  7. 11.  5. 11.  3.  3.  5.  4.  4.  5.  5.
#    1.  1.  0.  1.]]

# %%
A = (medical_data[1:2])

# %%
npdiff = numpy.array([A])

# %%
B = numpy.diff(npdiff)

# %%
print (B)
# Out:
# [[[  1.   1.  -1.   1.  -1.   2.  -1.   0.   4.   4.   1.  -6.   4.  -5.
#      0.   3.   9.  -8.  -2.  12. -14.   8.  -7.   7.  -5.   4.  -6.   6.
#     -8.   0.   2.  -1.   0.   1.   0.  -4.   0.  -1.   1.]]]

# %%
print(B.shape)
# Out:
# (1, 1, 39)

# %%
print(A.shape)
# Out:
# (1, 40)

# %%
print(B)
# Out:
# [[[  1.   1.  -1.   1.  -1.   2.  -1.   0.   4.   4.   1.  -6.   4.  -5.
#      0.   3.   9.  -8.  -2.  12. -14.   8.  -7.   7.  -5.   4.  -6.   6.
#     -8.   0.   2.  -1.   0.   1.   0.  -4.   0.  -1.   1.]]]

# %%
print(medical_data)
# Out:
# [[0. 0. 1. ... 3. 0. 0.]
#  [0. 1. 2. ... 1. 0. 1.]
#  [0. 1. 1. ... 2. 1. 1.]
#  ...
#  [0. 0. 1. ... 3. 0. 0.]
#  [0. 1. 2. ... 1. 0. 1.]
#  [0. 1. 1. ... 2. 1. 1.]]

# %%
A = (medical_data[:6,30:])
print(A)
# Out:
# [[ 4.  4.  5.  7.  3.  4.  2.  3.  0.  0.]
#  [ 3.  5.  4.  4.  5.  5.  1.  1.  0.  1.]
#  [10.  5.  4.  2.  2.  3.  2.  2.  1.  1.]
#  [ 4.  4.  5.  7.  3.  4.  2.  3.  0.  0.]
#  [ 3.  5.  4.  4.  5.  5.  1.  1.  0.  1.]
#  [10.  5.  4.  2.  2.  3.  2.  2.  1.  1.]]

# %%
patient_2 = A[1,:]

# %%
print(patient_2)
# Out:
# [3. 5. 4. 4. 5. 5. 1. 1. 0. 1.]

# %%
patient_2_min = np.min(patient_2)

# %%
print(patient_2_min)
# Out:
# 0.0

# %%
print(B)
# Out:
# [[[  1.   1.  -1.   1.  -1.   2.  -1.   0.   4.   4.   1.  -6.   4.  -5.
#      0.   3.   9.  -8.  -2.  12. -14.   8.  -7.   7.  -5.   4.  -6.   6.
#     -8.   0.   2.  -1.   0.   1.   0.  -4.   0.  -1.   1.]]]

# %%
A = [1, 2, -10, 6]

# %%
number_1 = np.max(A)

# %%
print(number_1)
# Out:
# 6

# %%
x = 5
y = "my string"

# %%
x + 4
# Out:
# 9

# %%
newstring = " Mus musculus "

# %%
newstring.split()
# Out:
# ['Mus', 'musculus']

# %%
print(medical_data)
# Out:
# [[0. 0. 1. ... 3. 0. 0.]
#  [0. 1. 2. ... 1. 0. 1.]
#  [0. 1. 1. ... 2. 1. 1.]
#  ...
#  [0. 0. 1. ... 3. 0. 0.]
#  [0. 1. 2. ... 1. 0. 1.]
#  [0. 1. 1. ... 2. 1. 1.]]

# %%
s = "WHEN on board H.M.S. Beagle, as naturalist"

# %%
s.count(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-171-c41d574b352f> in <module>
# ----> 1 s.count(b)
#
# TypeError: must be str, not type

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-168-c41d574b352f> in <module>
# ----> 1 s.count(b)
#
# TypeError: must be str, not type
