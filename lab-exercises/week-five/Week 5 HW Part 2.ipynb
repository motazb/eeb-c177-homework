# %%
#1. for loop is used to rerun commands multiple times. This can be used to count or just repeat an operation many times automatically.

# %%
for x in range(1, 4):
    print(x)
# Out:
# 1
# 2
# 3

# %%
#2.
word = 'oxygen'
for char in word:
    print(char)
#the body of the loop is executed 6 times
# Out:
# o
# x
# y
# g
# e
# n

# %%
x = 1

# %%
#3.
for x in range (4,5):
    if x < 4096:
        x *= x
        print(x)
# Out:
# 16

# %%
#4.
a = ''
word = "Ucla"
for i in word:
        a = i + a
print(a)
# Out:
# alcU

# %%
#5.

a_list = ["apple", "banana", "mango"]
for idx, val in enumerate(a_list):
    print("fruit {}: {}".format(idx, val))
# Out:
# fruit 0: apple
# fruit 1: banana
# fruit 2: mango

# %%
x = 5
coefs = [2, 4, 3]
for x, y in enumerate(coefs):
    i=0    
    print((y =(coefs[i] * x**i)) + (y(coefs[i+1] * x**(i+1))))
# Out:
#   File "<ipython-input-12-8ffed3393034>", line 5
#     print((y =(coefs[i] * x**i)) + (y(coefs[i+1] * x**(i+1))))
#              ^
# SyntaxError: invalid syntax
