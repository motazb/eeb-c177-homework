# %%
GenomeSize = {"Homosapiens": 3200.0, "Escherichia coli": 4.6, "Arabiodopsis thaliana": 157.0}

# %%
GenomeSize.items()
# Out:
# dict_items([('Homosapiens', 3200.0), ('Escherichia coli', 4.6), ('Arabiodopsis thaliana', 157.0)])

# %%
for species, size in GenomeSize.items():
    print(species + " : " + str(size))
# Out:
# Homosapiens : 3200.0
# Escherichia coli : 4.6
# Arabiodopsis thaliana : 157.0

# %%
for key in GenomeSize.keys():
    print( "the genome size of " + key + " is " + str(GenomeSize[key]))
# Out:
# the genome size of Homosapiens is 3200.0
# the genome size of Escherichia coli is 4.6
# the genome size of Arabiodopsis thaliana is 157.0

# %%
GenomeSize["Homosapiens"]
# Out:
# 3200.0

# %%
GenomeSize["triggerfish"] = 100.0
GenomeSize.keys()
# Out:
# dict_keys(['Homosapiens', 'Escherichia coli', 'Arabiodopsis thaliana', 'triggerfish'])

# %%
from collections import defaultdict

food_list = 'spam spam spam spam spam spam eggs spam'.split()
food_list
# Out:
# ['spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'eggs', 'spam']

# %%
food_count = defaultdict(int) #default value of int is 0
for food in food_list:
    food_count[food] += 1 #increment element's value by 1
food_count
# Out:
# defaultdict(int, {'spam': 7, 'eggs': 1})

# %%
GenomeSize.get("Homosapiens")
# Out:
# 3200.0

# %%
#Check course website for commands

# %%
list1 = ["name", "age", "height"]
list2 = ["bernie", 78, "72"]

# %%
pres_dict = dict(zip(list1,list2))

pres_dict.items()
# Out:
# dict_items([('name', 'bernie'), ('age', 78), ('height', '72')])

# %%
a = [5,6,7,7,7,8,9,9]

# %%
b = set(a)

# %%
b
# Out:
# {5, 6, 7, 8, 9}

# %%
tuple_example = ("a", "b", "c")
list_example = ["a", "b", "c"]

# %%
list_example.pop()
# Out:
# 'c'

# %%
tuple_example.pop()
#tuples are immutable. You can't change them.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-4a9e1f2a3d9d> in <module>
# ----> 1 tuple_example.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
apes = ["Pan", "Homo", "Gorilla"]

for ape in apes:
    print(ape, "is an ape")
# Out:
# Pan is an ape
# Homo is an ape
# Gorilla is an ape

# %%
for ape in apes:
    print(ape + " is an ape")
# Out:
# Pan is an ape
# Homo is an ape
# Gorilla is an ape

# %%
for ape in apes:
    name_length = len(ape)
    first_letter = ape[0]
    print(ape + " is an ape. Its name starts with " + first_letter)
    print("its name has " + str(name_length) + " letters")
# Out:
# Pan is an ape. Its name starts with P
# its name has 3 letters
# Homo is an ape. Its name starts with H
# its name has 4 letters
# Gorilla is an ape. Its name starts with G
# its name has 7 letters

# %%
nn = [1,2,3,4,5]

for number in nn:
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for ii in range(5):
    print(ii + 1)
# Out:
# 1
# 2
# 3
# 4
# 5
