# %%
#1.
#A list is a collection of things and can be edited

# %%
#2.
#To create a list, pick a name for the list, then put an equal sign, then in between brackets put each of your items, and place commas between every item.
#To index a value in the list, pick a name for the index, then put an equal sign, then put the name of the list, period, index, and in parenthesis put the value you want to index.

# %%
#3.
#put the name of the list, period, then the kind of change to the values you want to implement.

# %%
#4.
#a) list.append(5) this appends a 5 to the existing list
#b) 
list = [1, 2, 10, 9]
list[len(list):] = [7]
print(list)
# Out:
# [1, 2, 10, 9, 7]

# %%
#5.
def split(word):
    return [char for char in word]
word = 'hello'
print(split(word))
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
#6.
string = "Observation data: 02-Feb-2013"
string[-4:]
# Out:
# '2013'

# %%
#6.
list = [["fluorine", "F"],
                 ["chlorine", "Cl"],
                 ["bromine", "Br"],
                 ["iodine", "I"],
                 ["astatine", "At"]]
list[-4:]
# Out:
# [['chlorine', 'Cl'], ['bromine', 'Br'], ['iodine', 'I'], ['astatine', 'At']]

# %%
#7. Yes, it would.

# %%
beatles = "In an octopus's garden in the shade"
newstring = beatles[0:35:2]
print(newstring)
# Out:
# I notpssgre ntesae
