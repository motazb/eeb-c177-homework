# %%
import pandas as pd

# %%
tmp_data = pd.read_csv('blake.csv')
data = tmp_data.to_numpy()

# %%
#1.
repcountries = data[0:,1]
countries = set(repcountries)
print(countries)
# Out:
# {'Mexico', 'Uganda', 'Canada', 'India', 'Peru', 'US', 'Senegal'}

# %%
from collections import defaultdict

Gender_list = data[0:,4]
Gendercounts= defaultdict(int)
print(Gendercounts)
# Out:
# defaultdict(<class 'int'>, {})

# %%
for Genders in Gender_list:
    Gendercounts[Genders] += 1
print(Gendercounts)
# Out:
# defaultdict(<class 'int'>, {'F': 14112, 'M': 13600})
