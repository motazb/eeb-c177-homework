# %%
import numpy
import pandas as pd

# %%
tmp_data = pd.read_csv('patientdata.csv')
data = tmp_data.to_numpy()

# %%
age = data[:,4]
#This names all the rows in column 4 to be called "age"

# %%
age_min = numpy.min(age)

# %%
print(age_min)
#This gives me the lowest age in the set
# Out:
# 0

# %%
print(data.shape)
#This says my data has 334839 rows and 12 columns
# Out:
# (334839, 12)

# %%
age_max = numpy.max(age)

# %%
print(age_max)
#This gives me the largest age in the set
# Out:
# 107

# %%
age_mean = numpy.mean(age)

# %%
print (age_mean)
#This gives me the average age
# Out:
# 31.38545091820248

# %%
Patient_1_weight = data[0,2]

# %%
pt_1 = "Patient 1 weighs:"

# %%
print(pt_1, Patient_1_weight)
# Out:
# Patient 1 weighs: 15.7762

# %%
First5 = data[:5,4:7]

# %%
print(First5)
#gives me the age, sex, and race of the first 5 patients
# Out:
# [[5 'Male' nan]
#  [36 'Male' 'White']
#  [20 'Female' nan]
#  [61 'Male' nan]
#  [88 'Female' 'Other']]

# %%
#Potential questions I can ask using my data is what are all the races from the data collected? How many of each? Which body part is most commonly affected?
