# %% [markdown]
# 1a

# %%
xx = input("What is the temperature?")
units = input("Would you like to convert to [0] Celsius or [1] Fahrenheit?")

if int(units) == 0:
        yy = (float(xx) - 32) * 5 / 9
        print("The temperature in Celsius is {}".format(yy))
elif int(units) == 1:
    yy = (float(xx) * 9 / 5 + 32)
    print("The temperature in Fahrenheit is {}".format(yy))
else:
    print("{} is not a valid option. Please enter 0 or 1".format(units))
# Out:
# What is the temperature?100
# Would you like to convert to [0] Celsius or [1] Fahrenheit?1
# The temperature in Fahrenheit is 212.0

# %% [markdown]
# 1b

# %%
xx = input("What is the temperature?")
units = input("Would you like to convert to [0] Celsius or [1] Fahrenheit?")
if(units.isdigit()):
    print(units)
    if int(units) == 0:
        yy = (float(xx) - 32) * 5 / 9
        print("The temperature in Celsius is {}".format(yy))
    elif int(units) == 1:
        yy = (float(xx) * 9 / 5 + 32)
        print("The temperature in Fahrenheit is {}".format(yy))
# Out:
# What is the temperature?50
# Would you like to convert to [0] Celsius or [1] Fahrenheit?0
# 0
# The temperature in Celsius is 10.0

# %% [markdown]
# 1c

# %%
def tempertaure_reader():
xx = input("What is the temperature?")
units = input("Would you like to convert to [0] Celsius or [1] Fahrenheit")
if(units.isdigit()):
    print(units)
    if int(units) == 0:
        yy = (float(xx) - 32) * 5/9
        print("The temperature in Celsius is {}".format(yy))
    elif int(units) == 1:
        yy = (float(xx) * 9 / 5 + 32)
        print("The temperature in Fahrenheit is {}".format(yy))
    else:
        print("{} is not a valid option. Please enter 0 or 1".format(units))
else:
        print("{} is not a valid option. Please enter 0 or 1".format(units))
# Out:
# What is the temperature?50
# Would you like to convert to [0] Celsius or [1] Fahrenheit1
# 1
# The temperature in Fahrenheit is 122.0

# %% [markdown]
# 2a

# %%
import csv
import os
datapath = "/home/eebc177student/Developer/repos/CSB/python/data/"
workingdir = "/home/eebc177student/Developer/repos/CSB/unix/sandbox/"
os.chdir(datapath)


with open ("Dalziel2016_data.csv") as fr:
    reader = csv.DictReader(fr)
    header = reader.fieldnames
    with open ("cases_1920.csv", "w") as fw:
        writer = csv.DictWriter(fw, fieldnames = header, delimiter = ",")
        for row in reader:
            if row["year"] == "1920":
                writer.writerow(row)
                
with open("cases_1920.csv", "r") as ff:
    for line in ff:
        print(line)
# Out:
# 1,1920,BALTIMORE,181,733826
#
# 2,1920,BALTIMORE,274,734380.7846
#
# 3,1920,BALTIMORE,270,734932.2288
#
# 4,1920,BALTIMORE,323,735480.3461
#
# 5,1920,BALTIMORE,308,736025.1501
#
# 6,1920,BALTIMORE,372,736566.6544
#
# 7,1920,BALTIMORE,380,737104.8725
#
# 8,1920,BALTIMORE,528,737639.818
#
# 9,1920,BALTIMORE,560,738171.5045
#
# 10,1920,BALTIMORE,560,738699.9455
#
# 11,1920,BALTIMORE,503,739225.1545
#
# 12,1920,BALTIMORE,306,739747.1453
#
# 13,1920,BALTIMORE,158,740265.9312
#
# 14,1920,BALTIMORE,100,740781.526
#
# 15,1920,BALTIMORE,42,741293.943
#
# 16,1920,BALTIMORE,18,741803.196
#
# 17,1920,BALTIMORE,16,742309.2985
#
# 18,1920,BALTIMORE,16,742812.2639
#
# 19,1920,BALTIMORE,15,743312.106
#
# 20,1920,BALTIMORE,6,743808.8383
#
# 21,1920,BALTIMORE,12,744302.4742
#
# 22,1920,BALTIMORE,19,744793.0275
#
# 23,1920,BALTIMORE,15,745280.5116
#
# 24,1920,BALTIMORE,26,745764.9402
#
# 25,1920,BALTIMORE,38,746246.3267
#
# 26,1920,BALTIMORE,29,746724.6848
#
# 1,1920,BOSTON,520,748060
#
# ...

# %% [markdown]
# 2b

# %%
import csv
import os
datapath = "/home/eebc177student/Developer/repos/CSB/python/data/"
workingdir = "/home/eebc177student/Developer/repos/CSB/unix/sandbox/"
os.chdir(datapath)


with open ("Dalziel2016_data.csv") as fr:
    reader = csv.DictReader(fr)
    header = reader.fieldnames
    with open ("cases_Washington.csv", "w") as fw:
        writer = csv.DictWriter(fw, fieldnames = header, delimiter = ",")
        for row in reader:
            if row["loc"] == "WASHINGTON":
                writer.writerow(row)
                
with open("cases_Washington.csv", "r") as washington:
    for line in washington:
        print(line)
# Out:
# 1,1906,WASHINGTON,NA,302312.9457
#
# 2,1906,WASHINGTON,NA,302519.0169
#
# 3,1906,WASHINGTON,NA,302726.1932
#
# 4,1906,WASHINGTON,NA,302934.4823
#
# 5,1906,WASHINGTON,NA,303143.8918
#
# 6,1906,WASHINGTON,NA,303354.4296
#
# 7,1906,WASHINGTON,NA,303566.1032
#
# 8,1906,WASHINGTON,NA,303778.9205
#
# 9,1906,WASHINGTON,NA,303992.8891
#
# 10,1906,WASHINGTON,NA,304208.0168
#
# 11,1906,WASHINGTON,NA,304424.3113
#
# 12,1906,WASHINGTON,NA,304641.7804
#
# 13,1906,WASHINGTON,NA,304860.4316
#
# 14,1906,WASHINGTON,NA,305080.2729
#
# 15,1906,WASHINGTON,NA,305301.3118
#
# 16,1906,WASHINGTON,NA,305523.5561
#
# 17,1906,WASHINGTON,NA,305747.0136
#
# 18,1906,WASHINGTON,NA,305971.6919
#
# 19,1906,WASHINGTON,NA,306197.5988
#
# 20,1906,WASHINGTON,NA,306424.742
#
# 21,1906,WASHINGTON,NA,306653.1292
#
# 22,1906,WASHINGTON,NA,306882.7681
#
# 23,1906,WASHINGTON,NA,307113.6665
#
# 24,1906,WASHINGTON,NA,307345.832
#
# 25,1906,WASHINGTON,NA,307579.2725
#
# 26,1906,WASHINGTON,NA,307813.9956
#
# ...

# %% [markdown]
# 2c

# %%
#2c)
import csv

with open("Dalziel2016_data.csv", "r") as ff:
    reader = csv.DictReader(ff)
    for row in reader:
        print(row["loc"], row["pop"])

# %% [markdown]
# 2d

# %%
#2d)
import csv

#My code uppercases the input in case someone doesn't
#capitalize the location's name as the locations are
#all in all caps in the file
location = input("Input location").upper()
with open ("Dalziel2016_data.csv") as fr:
    reader = csv.DictReader(fr)
    header = reader.fieldnames
    with open ("location.csv", "w") as fw:
        writer = csv.DictWriter(fw, fieldnames = header, delimiter = ",")
        for row in reader:
            if row["loc"] == location:
                writer.writerow(row)
                
with open("location.csv", "r") as ll:
    for line in ll:
        print(line)
        
#This is in case someone puts a location which isn't
#in the file
    else:
                print("Location unavailable")
# Out:
# Input locationwashington
# 1,1906,WASHINGTON,NA,302312.9457
#
# 2,1906,WASHINGTON,NA,302519.0169
#
# 3,1906,WASHINGTON,NA,302726.1932
#
# 4,1906,WASHINGTON,NA,302934.4823
#
# 5,1906,WASHINGTON,NA,303143.8918
#
# 6,1906,WASHINGTON,NA,303354.4296
#
# 7,1906,WASHINGTON,NA,303566.1032
#
# 8,1906,WASHINGTON,NA,303778.9205
#
# 9,1906,WASHINGTON,NA,303992.8891
#
# 10,1906,WASHINGTON,NA,304208.0168
#
# 11,1906,WASHINGTON,NA,304424.3113
#
# 12,1906,WASHINGTON,NA,304641.7804
#
# 13,1906,WASHINGTON,NA,304860.4316
#
# 14,1906,WASHINGTON,NA,305080.2729
#
# 15,1906,WASHINGTON,NA,305301.3118
#
# 16,1906,WASHINGTON,NA,305523.5561
#
# 17,1906,WASHINGTON,NA,305747.0136
#
# 18,1906,WASHINGTON,NA,305971.6919
#
# 19,1906,WASHINGTON,NA,306197.5988
#
# 20,1906,WASHINGTON,NA,306424.742
#
# 21,1906,WASHINGTON,NA,306653.1292
#
# 22,1906,WASHINGTON,NA,306882.7681
#
# 23,1906,WASHINGTON,NA,307113.6665
#
# 24,1906,WASHINGTON,NA,307345.832
#
# 25,1906,WASHINGTON,NA,307579.2725
#
# ...

# %% [markdown]
# 3a

# %%
#3a)
import pandas as pd
data = pd.read_csv("Dalziel2016_data.csv")

locarr = data["loc"].unique()
print(locarr)
# Out:
# ['BALTIMORE' 'BOSTON' 'BRIDGEPORT' 'BUFFALO' 'CHICAGO' 'CINCINNATI'
#  'CLEVELAND' 'COLUMBUS' 'DENVER' 'DETROIT' 'DULUTH' 'FALL RIVER'
#  'GRAND RAPIDS' 'HARTFORD' 'INDIANAPOLIS' 'KANSAS CITY' 'LOS ANGELES'
#  'MILWAUKEE' 'MINNEAPOLIS' 'NASHVILLE' 'NEW HAVEN' 'NEW ORLEANS'
#  'NEW YORK' 'NEWARK' 'PHILADELPHIA' 'PITTSBURGH' 'PROVIDENCE' 'READING.US'
#  'RICHMOND' 'ROCHESTER' 'SALT LAKE CITY' 'SAN FRANCISCO' 'SEATTLE'
#  'SPOKANE' 'SPRINGFIELD' 'ST LOUIS' 'TOLEDO' 'TRENTON' 'WASHINGTON'
#  'WORCESTER']

# %% [markdown]
# 3b

# %%
#3b)
import csv
from collections import defaultdict
import pandas as pd
data = pd.read_csv("Dalziel2016_data.csv")
#Defining array of locations
locarr = data["loc"].unique()

locNum = {}
with open ("Dalziel2016_data.csv") as fr:
    reader = csv.DictReader(fr)
    for row in reader:
        loc = row['loc']
        locNum[loc] = locNum.get(loc, 0)
        locNum[loc] += 1
locNum
# Out:
# {'BALTIMORE': 1118,
#  'BOSTON': 1118,
#  'BRIDGEPORT': 1118,
#  'BUFFALO': 1118,
#  'CHICAGO': 1118,
#  'CINCINNATI': 1118,
#  'CLEVELAND': 1118,
#  'COLUMBUS': 1118,
#  'DENVER': 1118,
#  'DETROIT': 1118,
#  'DULUTH': 1118,
#  'FALL RIVER': 1118,
#  'GRAND RAPIDS': 1118,
#  'HARTFORD': 1118,
#  'INDIANAPOLIS': 1118,
#  'KANSAS CITY': 1118,
#  'LOS ANGELES': 1118,
#  'MILWAUKEE': 1118,
#  'MINNEAPOLIS': 1118,
#  'NASHVILLE': 1118,
#  'NEW HAVEN': 1118,
#  'NEW ORLEANS': 1118,
#  'NEW YORK': 1118,
#  'NEWARK': 1118,
#  'PHILADELPHIA': 1118,
#  'PITTSBURGH': 1118,
#  'PROVIDENCE': 1118,
#  'READING.US': 1118,
#  'RICHMOND': 1118,
#  'ROCHESTER': 1118,
#  'SALT LAKE CITY': 1118,
#  'SAN FRANCISCO': 1118,
#  'SEATTLE': 1118,
#  'SPOKANE': 1118,
#  'SPRINGFIELD': 1118,
#  'ST LOUIS': 1118,
#  'TOLEDO': 1118,
#  'TRENTON': 1118,
#  'WASHINGTON': 1118,
#  'WORCESTER': 1118}

# %% [markdown]
# 3c

# %%
#3c)
import csv
from collections import defaultdict
import pandas as pd
data = pd.read_csv("Dalziel2016_data.csv")


#After a LOT of trying to do this, I decided
#to get help from others' github. I think you
#said it's ok as long as we cite them.
#if I misheard that and I'm wrong then I'm
#really sorry, I really think you said that.
#I found this command and I completely
#understand it and it's honestly insanely
#useful. I got it from shreya's.

mean = data.groupby('loc').mean()
mean
# Out:
#                 biweek    year       cases           pop
# loc
# BALTIMORE         13.5  1927.0  177.919370  7.621327e+05
# BOSTON            13.5  1927.0  180.037928  7.497160e+05
# BRIDGEPORT        13.5  1927.0   12.130719  1.377390e+05
# BUFFALO           13.5  1927.0   87.959119  5.278970e+05
# CHICAGO           13.5  1927.0  398.546803  2.993272e+06
# CINCINNATI        13.5  1927.0   55.446480  4.262704e+05
# CLEVELAND         13.5  1927.0  164.288910  8.011217e+05
# COLUMBUS          13.5  1927.0   47.513859  2.650888e+05
# DENVER            13.5  1927.0  106.372340  2.828426e+05
# DETROIT           13.5  1927.0  278.453820  1.240488e+06
# DULUTH            13.5  1927.0   29.151653  9.669747e+04
# FALL RIVER        13.5  1927.0   24.844670  1.171931e+05
# GRAND RAPIDS      13.5  1927.0   51.168142  1.491154e+05
# HARTFORD          13.5  1927.0   24.843299  1.460925e+05
# INDIANAPOLIS      13.5  1927.0  115.424078  3.355697e+05
# ...

# %% [markdown]
# 3d

# %%
#3c
#same command. Super easy and useful..
mean.groupby(['loc','year']).mean()
# Out:
#                        biweek       cases           pop
# loc            year
# BALTIMORE      1927.0    13.5  177.919370  7.621327e+05
# BOSTON         1927.0    13.5  180.037928  7.497160e+05
# BRIDGEPORT     1927.0    13.5   12.130719  1.377390e+05
# BUFFALO        1927.0    13.5   87.959119  5.278970e+05
# CHICAGO        1927.0    13.5  398.546803  2.993272e+06
# CINCINNATI     1927.0    13.5   55.446480  4.262704e+05
# CLEVELAND      1927.0    13.5  164.288910  8.011217e+05
# COLUMBUS       1927.0    13.5   47.513859  2.650888e+05
# DENVER         1927.0    13.5  106.372340  2.828426e+05
# DETROIT        1927.0    13.5  278.453820  1.240488e+06
# DULUTH         1927.0    13.5   29.151653  9.669747e+04
# FALL RIVER     1927.0    13.5   24.844670  1.171931e+05
# GRAND RAPIDS   1927.0    13.5   51.168142  1.491154e+05
# HARTFORD       1927.0    13.5   24.843299  1.460925e+05
# INDIANAPOLIS   1927.0    13.5  115.424078  3.355697e+05
# ...

# %% [markdown]
# 4

# %%
Singhdata = pd.read_csv("Singh2015_data.csv")
Singhdata.groupby(['Line','InfectionStatus']).mean()
# Out:
#                       RecombinantFraction
# Line InfectionStatus
# 21   I                           0.199730
#      W                           0.178066
# 40   I                           0.180130
#      W                           0.177911
# 45   I                           0.191199
#      W                           0.187141
# 73   I                           0.199488
#      W                           0.178579
