# %%
#8.1
e2f = {"dog": "chien", "cat": "chat", "walrus": "morse"}

# %%
#8.2
e2f["walrus"]
# Out:
# 'morse'

# %%
#8.3
f2e = dict([(value,key) for key,value in e2f.items()])
print(f2e)
# Out:
# {'chien': 'dog', 'chat': 'cat', 'morse': 'walrus'}

# %%
#8.4
f2e["chien"]
# Out:
# 'dog'

# %%
#8.5
e2f.keys()
# Out:
# dict_keys(['dog', 'cat', 'walrus'])

# %%
#8.6
cats = ['Henri', 'Grumpy', 'Lucy']
octopi = {}
emus = {}
animals = {'cats': cats, 'octopi': octopi, 'emus': emus}
plants = {}
other = {}
life = {'animals': animals, 'plants': plants, 'other': other}
print(life)
# Out:
# {'animals': {'cats': ['Henri', 'Grumpy', 'Lucy'], 'octopi': {}, 'emus': {}}, 'plants': {}, 'other': {}}

# %%
#8.7
print(life.keys())
# Out:
# dict_keys(['animals', 'plants', 'other'])

# %%
#8.8
life['animals'].keys()
# Out:
# dict_keys(['cats', 'octopi', 'emus'])

# %%
#8.9
print(life['animals']['cats'])
# Out:
# ['Henri', 'Grumpy', 'Lucy']

# %%
#8.10
squares = dict()
for x in range (10):
    squares[x]=x**2
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
#8.11
odd = {number for number in range(10) if number % 2 > 0}
print(odd)
# Out:
# {1, 3, 5, 7, 9}

# %%
#8.12
numbers = range(10)
for numbers in range(10):
    print('Got ' + str(numbers))
# Out:
# Got 0
# Got 1
# Got 2
# Got 3
# Got 4
# Got 5
# Got 6
# Got 7
# Got 8
# Got 9

# %%
#8.13
key_tuple = ('optimist', 'pessimist', 'troll')
value_tuple = ('The glass is half full', 'The glass is half empty', 'How did you get a glass?')
dict(zip(key_tuple, value_tuple))
# Out:
# {'optimist': 'The glass is half full',
#  'pessimist': 'The glass is half empty',
#  'troll': 'How did you get a glass?'}

# %%
#8.14
titles = ['Creature of Habit', 'Crewel Fate', 'Sharks On a Plan']
plots = ['A nun turns into a monster', 'A haunted yarn shop', 'Check your exits']
movies = dict(zip(titles, plots))
print(movies)
# Out:
# {'Creature of Habit': 'A nun turns into a monster', 'Crewel Fate': 'A haunted yarn shop', 'Sharks On a Plan': 'Check your exits'}
